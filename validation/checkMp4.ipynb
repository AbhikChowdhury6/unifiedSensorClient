# %%
#we'll take in a file name and path
#we'll parse out the start time and end time
#we'll parse out the true frame rate

#we'll parse out the frame shape


#I would like to get the relative indexs of the iframes
#I would like to 

#I would like to be able to generate chopping commands 


#TODO:
#how about we actually just use 1fps for the timelapse and we just deal with that data growth
#that would make an iframe every 4 or so minutes
