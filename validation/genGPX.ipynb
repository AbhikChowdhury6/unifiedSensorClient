# %%
#so we're going to be loading a wavpak file

# %%
output_file_name = "output.gpx"

# %%
import sys
sys.path.insert(0, "/home/chowder/Documents/unifiedSensorClient")

import platformUtils.logUtils  # register TRACE level and Logger.trace
from writers.wavpakOutput import wavpak_output
import pandas as pd
from datetime import datetime, timezone
import logging

# Print logs from wavpak_output in this notebook
logging.basicConfig(
    level=logging.DEBUG,  # use "trace" level by setting debug_lvl="trace" below
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
    handlers=[logging.StreamHandler(sys.stdout)],
    force=True,
)

file_name = "20260113T054207p000Z_20260113T054249p000Z.wv"
start_dt = datetime.strptime(file_name.split("_")[0], "%Y%m%dT%H%M%Sp%fZ").replace(tzinfo=timezone.utc)

descriptor = "c57d828b-e8d1-433b-ad79-5420d2136d3f_serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable"
file_base_path = "/home/chowder/Documents/unifiedSensorClient/validation/exampleGPSData/" \
    + descriptor + "/" + start_dt.strftime("%Y/%m/%d/")

file_path = file_base_path + file_name

topic = "serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable"
output_hz = "variable"
debug_lvl = 5

#instantiate a wavpak output and call load_file
additional_output_config = {
    "input_dtype_str": "float32",
    "wv_dtype_str": "int32",
    "float_bits": 23,
    "bits": 32,
    "sign": "s",
    "channels": 3
}

wavpak_output_obj = wavpak_output( 
            output_base=topic,
            output_hz=output_hz, #variable hz
            temp_write_location="/tmp/",
            debug_lvl=debug_lvl,
            **additional_output_config)
    
timestamps, data_array = wavpak_output_obj.load_file(file_path)
# Out:
# 2026-01-12 22:44:50,421 INFO serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output starting
# 2026-01-12 22:44:50,422 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output debug lvl: 5
# 2026-01-12 22:44:50,423 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output input dtype: float32
# 2026-01-12 22:44:50,423 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output wv dtype: int32
# 2026-01-12 22:44:50,423 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output float bits: 23
# 2026-01-12 22:44:50,423 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output bits: 32
# 2026-01-12 22:44:50,424 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output sign: s
# 2026-01-12 22:44:50,424 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output endian: le
# 2026-01-12 22:44:50,424 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output channels: 3
# 2026-01-12 22:44:50,425 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output output hz: variable
# 2026-01-12 22:44:50,426 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output temp output location: /tmp/serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable/
# 2026-01-12 22:44:50,426 INFO serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: s 32
# 2026-01-12 22:44:50,426 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output persist location: /tmp/serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_persist/
# 2026-01-12 22:44:50,430 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output:  raw data: b'\xb6\xcb\xd2\x00\x00\x00\xf0\x02\xc0)\xa9\x10\xb6\xcb\xd2\x00\x00\x00\x00\x03\xc0)\xa9\x10\xb6\xcb\xd2\x00\x00\x00\x10\x03\xc0)\xa9\x10\xb6\xcb\xd2\x00\x00\x00 \x03\xc0)\xa9\x10\xb6\xcb\xd2\x00\x00\x000\x03\xc0)\xa9\x10\xb6\xcb\xd2\x00\x00\x00@\x03\xc0)\xa9\x10\xb6\xcb\xd2\x00\x00\x00P\x03\xc0)\xa9\x10\xb6\xcb\xd2\x00\x00\x00`\x03\xc0)\xa9\x10\xb6\xcb\xd2\x00'
# 2026-01-12 22:44:50,430 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output:  wv dtype: int32
# 2026-01-12 22:44:50,430 DEBUG serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output
ial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: data_raw: [279521728  51380224  13814710 279521728  56623104  13814710 279521728
#   61865984  13814710 279521728  67108864  13814710 279521728  72351744
#   13814710 279521728  77594624  13814710 279521728  82837504  13814710
#  279521728  88080384  13814710 279521728]
# 2026-01-12 22:44:50,435 TRACE serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output wv_int_to_float: data: [33.321587   6.125      1.6468418 33.321587   6.75       1.6468418
#  33.321587   7.375      1.6468418 33.321587   8.         1.6468418
#  33.321587   8.625      1.6468418 33.321587   9.25       1.6468418
#  33.321587   9.875      1.6468418 33.321587  10.5        1.6468418
#  33.321587 ]
# 2026-01-12 22:44:50,436 TRACE serial-0_cdtoptech-PA1616S_3d-fix_wgs84_int32-f23_wavpak-3_variable_wavpak-output: data_out: [33.321587   6.125      1.6468418 33.321587   6.75       1.6468418
#  33.321587   7.375      1.6468418 33.321587   8.         1.6468418
#  33.321587   8.625      1.6468418 33.321587   9.25       1.6468418
#  33.321587   9.875      1.6468418 33.321587  10.5        1.6468418
#  33.321587 ]

# %%
data_array.shape
# Out:
# (2107,)

# %%
timestamps.shape
# generate a dataframe based on timestamps (int64 ns) and lat/lon/alt data
# Out:
# (2107,)

# %%
timestamps
# Out:
# array([ 1768271479000000000, -1114995334244454232, -2072180991139006616,
#        ..., -1114959878244425232,  1207959818570809000,
#         1768275339000000000])

# %%
# generate a dataframe based on timestamps (int64 ns) and lat/lon/alt data
import numpy as np

colNames = ["sampleDT", "lat", "lon", "wgsAltKm"]

# ensure data_array is shaped (n_samples, 3)
if data_array.ndim == 1:
    if data_array.size % 3 != 0:
        raise ValueError("data_array length is not a multiple of 3; cannot form lat/lon/wgsAltKm triples")
    data_reshaped = data_array.reshape(-1, 3)
elif data_array.ndim == 2:
    if data_array.shape[1] >= 3:
        data_reshaped = data_array[:, :3]
    elif data_array.shape[1] == 1 and (data_array.size % 3 == 0):
        data_reshaped = data_array.reshape(-1, 3)
    else:
        raise ValueError("data_array has incompatible shape for lat/lon/wgsAltKm: " + str(data_array.shape))
else:
    raise ValueError("Unexpected data_array ndim: " + str(data_array.ndim))

# align lengths in case timestamps and data differ slightly
n = min(len(timestamps), len(data_reshaped))
if n == 0:
    raise ValueError("No samples to build DataFrame")

sampleDT = pd.to_datetime(timestamps[:n], unit='ns', utc=True)
df = pd.DataFrame(data_reshaped[:n], columns=colNames[1:])
df.insert(0, "sampleDT", sampleDT)

print(f"DataFrame shape: {df.shape}")
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 9
#       7 if data_array.ndim == 1:
#       8     if data_array.size % 3 != 0:
# ----> 9         raise ValueError("data_array length is not a multiple of 3; cannot form lat/lon/wgsAltKm triples")
#      10     data_reshaped = data_array.reshape(-1, 3)
#      11 elif data_array.ndim == 2:
#
# ValueError: data_array length is not a multiple of 3; cannot form lat/lon/wgsAltKm triples

# %%
#now with the dataframe with date`time, lat, long, and alt, we can start to generate the gpx file

#we'll be using gpxpy to generate the gpx file
import gpxpy
import gpxpy.gpx

gpx = gpxpy.gpx.GPX()

# Create a new track in the GPX file
gpx_track = gpxpy.gpx.GPXTrack()
gpx.tracks.append(gpx_track)
